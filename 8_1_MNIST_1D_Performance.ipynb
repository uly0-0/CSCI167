# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/vv/_7vtk_553m714738h8rtpqg00000gn/T/pip-req-build-r3q3gvqj
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/vv/_7vtk_553m714738h8rtpqg00000gn/T/pip-req-build-r3q3gvqj
#   Resolved https://github.com/greydanus/mnist1d to commit 68cb6b2d1d3a956cc2e9035e5a9860b66e33d642
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post15) (2.32.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post15) (2.1.1)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (from mnist1d==0.0.2.post15) (3.9.2)
# Collecting scipy (from mnist1d==0.0.2.post15)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (24.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post15) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post15) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post15) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post15) (2024.8.30)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post15) (1.16.0)
# Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_x86_64.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 39.9 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post15-py3-none-any.whl size=14561 sha256=90ebc23f64cc6ffae0f0275088bed3fc95ef4247e6dfe6678ca83c8100bc4666
#   Stored in directory: /private/var/folders/vv/_7vtk_553m714738h8rtpqg00000gn/T/pip-ephem-wheel-cache-h6byq_am/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: scipy, mnist1d
# Successfully installed mnist1d-0.0.2.post15 scipy-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i,D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k,D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k,D_o))


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, torch.nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'), dtype=torch.float32)
y_train = torch.tensor(data['y'].transpose().astype('int64'), dtype=torch.int64)
x_test= torch.tensor(data['x_test'].astype('float32'), dtype=torch.float32)
y_test = torch.tensor(data['y_test'].astype('int64'), dtype=torch.int64)

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.612086, train error 63.08,  test loss 1.714624, test error 67.20
# Epoch     1, train loss 1.323053, train error 48.33,  test loss 1.485015, test error 58.40
# Epoch     2, train loss 1.140534, train error 41.72,  test loss 1.359334, test error 55.30
# Epoch     3, train loss 0.982965, train error 35.22,  test loss 1.269235, test error 50.70
# Epoch     4, train loss 0.864533, train error 30.47,  test loss 1.217968, test error 47.80
# Epoch     5, train loss 0.794658, train error 29.05,  test loss 1.166817, test error 45.50
# Epoch     6, train loss 0.720983, train error 25.97,  test loss 1.190865, test error 44.70
# Epoch     7, train loss 0.647627, train error 22.45,  test loss 1.138568, test error 42.90
# Epoch     8, train loss 0.591821, train error 21.07,  test loss 1.168726, test error 43.30
# Epoch     9, train loss 0.509178, train error 16.85,  test loss 1.108398, test error 41.70
# Epoch    10, train loss 0.414341, train error 11.90,  test loss 1.100920, test error 40.90
# Epoch    11, train loss 0.376161, train error 9.75,  test loss 1.095359, test error 38.90
# Epoch    12, train loss 0.348781, train error 9.40,  test loss 1.113634, test error 39.30
# Epoch    13, train loss 0.333608, train error 9.45,  test loss 1.154151, test error 38.90
# Epoch    14, train loss 0.297411, train error 7.50,  test loss 1.168816, test error 40.00
# Epoch    15, train loss 0.277267, train error 6.80,  test loss 1.200134, test error 38.70
# Epoch    16, train loss 0.247896, train error 5.25,  test loss 1.220773, test error 39.60
# Epoch    17, train loss 0.229778, train error 4.68,  test loss 1.214399, test error 38.90
# Epoch    18, train loss 0.207208, train error 4.15,  test loss 1.252898, test error 38.60
# Epoch    19, train loss 0.189500, train error 3.45,  test loss 1.278407, test error 39.00
# Epoch    20, train loss 0.163180, train error 2.28,  test loss 1.252338, test error 37.90
# Epoch    21, train loss 0.151913, train error 1.93,  test loss 1.261807, test error 38.30
# Epoch    22, train loss 0.144994, train error 1.60,  test loss 1.291163, test error 38.60
# Epoch    23, train loss 0.139604, train error 1.62,  test loss 1.294566, test error 38.20
# Epoch    24, train loss 0.135637, train error 1.47,  test loss 1.306186, test error 38.70
# Epoch    25, train loss 0.127394, train error 1.12,  test loss 1.314197, test error 38.00
# Epoch    26, train loss 0.116671, train error 1.00,  test loss 1.327151, test error 38.40
# Epoch    27, train loss 0.113178, train error 0.82,  test loss 1.355095, test error 38.20
# Epoch    28, train loss 0.106095, train error 0.70,  test loss 1.345795, test error 38.40
# Epoch    29, train loss 0.100840, train error 0.55,  test loss 1.370618, test error 38.70
# Epoch    30, train loss 0.096339, train error 0.43,  test loss 1.371735, test error 38.10
# Epoch    31, train loss 0.093924, train error 0.43,  test loss 1.376577, test error 38.60
# Epoch    32, train loss 0.091105, train error 0.32,  test loss 1.378848, test error 38.60
# Epoch    33, train loss 0.088975, train error 0.35,  test loss 1.388345, test error 38.20
# Epoch    34, train loss 0.086846, train error 0.25,  test loss 1.392912, test error 38.30
# Epoch    35, train loss 0.085774, train error 0.30,  test loss 1.406023, test error 38.30
# Epoch    36, train loss 0.082845, train error 0.18,  test loss 1.405089, test error 38.10
# Epoch    37, train loss 0.081108, train error 0.18,  test loss 1.406911, test error 37.80
# Epoch    38, train loss 0.079308, train error 0.12,  test loss 1.415120, test error 38.10
# Epoch    39, train loss 0.077864, train error 0.20,  test loss 1.425147, test error 38.10
# Epoch    40, train loss 0.076265, train error 0.10,  test loss 1.426069, test error 38.10
# Epoch    41, train loss 0.075377, train error 0.10,  test loss 1.425959, test error 37.80
# Epoch    42, train loss 0.074289, train error 0.10,  test loss 1.431626, test error 38.20
# Epoch    43, train loss 0.073522, train error 0.10,  test loss 1.429357, test error 38.20
# Epoch    44, train loss 0.072703, train error 0.10,  test loss 1.435335, test error 38.20
# Epoch    45, train loss 0.071865, train error 0.10,  test loss 1.440658, test error 38.20
# Epoch    46, train loss 0.071163, train error 0.10,  test loss 1.439167, test error 38.30
# Epoch    47, train loss 0.070236, train error 0.10,  test loss 1.444661, test error 38.00
# Epoch    48, train loss 0.069757, train error 0.10,  test loss 1.447033, test error 38.20
# Epoch    49, train loss 0.068867, train error 0.10,  test loss 1.453044, test error 38.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
